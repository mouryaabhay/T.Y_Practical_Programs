# %%
# example

from sympy import *
# x,y = symbols('x,y')
A = Point(0,0)
B = Point(5,0)
C = Point(3,3)

T = Triangle(A,B,C)
print("Area: ", T.area)
print("Perimeter: ", T.perimeter)
# Out:
# Area:  15/2
# Perimeter:  sqrt(13) + 3*sqrt(2) + 5

# %%
# 1
A = Point(0,0)
B = Point(1,0)
C = Point(2,2)
D = Point(1,4)

P = Polygon(A,B,C,D)
print("Area: ", P.area)
print("Perimeter: ", P.perimeter)
# Out:
# Area:  4
# Perimeter:  1 + sqrt(17) + 2*sqrt(5)

# %%
# 2
P = RegularPolygon((0,0),5,8)
print("Area: ", P.area)
print("Perimeter: ", P.perimeter)
# Out:
# Area:  (400 - 200*sqrt(2))/(-4 + 4*sqrt(2))
# Perimeter:  40*sqrt(2 - sqrt(2))

# %%
# 3
P = RegularPolygon((2,2),1.5,7)
print("Reflect (x-y-5): ")
P.reflect(Line(x-y-5))
# Out:
# Reflect (x-y-5):
# RegularPolygon(Point2D(7, -3), -1.50000000000000, 7, 3*pi/14)

# %%
# 4
from math import pi

A = Point(0,0)
B = Point(2,0)
C = Point(2,3)
D = Point(1,6)

P = Polygon(A,B,C,D)
P.rotate(pi)
# Out:
# Polygon(Point2D(0, 0), Point2D(-2, 244929359829471/1000000000000000000000000000000), Point2D(-2, -3), Point2D(-1, -6))

# %%
# 5
A = Point(1,0)
B = Point(2,-1)
C = Point(-1,3)

P = Polygon(A,B,C)
P.reflect(Line(y-3))
# Out:
# Triangle(Point2D(1, 6), Point2D(2, 7), Point2D(-1, 3))

# %%
# 6
A = Point(0,0)
B = Point(2,2)
C = Point(0,2)

T = Triangle(A,B,C)
print("A: ", T.angles[A])
print("B: ", T.angles[B])
print("C: ", T.angles[C])
# Out:
# A:  pi/4
# B:  pi/4
# C:  pi/2

# %%
# 7.1
A = Point(0,0)
B = Point(4,0)
C = Point(2,4)

T = Triangle(A,B,C)

print("Isosceles: ", T.is_isosceles())
print("Right: ", T.is_right())
print("Scalene: ", T.is_scalene())
# Out:
# Isosceles:  True
# Right:  False
# Scalene:  False

# %%
# 7.2
A = Point(0,0)
B = Point(4,0)
C = Point(4,3)

T = Triangle(A,B,C)

print("Isosceles: ", T.is_isosceles())
print("Right: ", T.is_right())
print("Scalene: ", T.is_scalene())
# Out:
# Isosceles:  False
# Right:  True
# Scalene:  True

# %%
# 7.3
A = Point(0,0)
B = Point(4,0)
C = Point(1,4)

T = Triangle(A,B,C)

print("Isosceles: ", T.is_isosceles())
print("Right: ", T.is_right())
print("Scalene: ", T.is_scalene())
# Out:
# Isosceles:  False
# Right:  False
# Scalene:  True

# %%
# 8.1
Triangle(sss=(3,4,5))
# Out:
# Triangle(Point2D(0, 0), Point2D(3, 0), Point2D(3, 4))

# %%
# 8.2
Triangle(asa=(30,1,30))
# Out:
# Triangle(Point2D(0, 0), Point2D(1, 0), Point2D(1/2, sqrt(3)/6))

# %%
# 8.3
Triangle(sas=(1,45,2))
# Out:
# Triangle(Point2D(0, 0), Point2D(2, 0), Point2D(sqrt(2)/2, sqrt(2)/2))
