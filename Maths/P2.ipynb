# %%
#example
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits import mplot3d

x = np.linspace(-2*np.pi, 2*np.pi, 100)
y = np.linspace(-2*np.pi, 2*np.pi, 100)
X, Y = np.meshgrid(x,y)
Z = np.cos(X + Y)

fig = plt.figure(figsize=(8,6))

ax=plt.axes(projection='3d')
ax.contour3D(X,Y,Z,50,cmap='viridis')
ax.set_xlabel('X-axis')
ax.set_ylabel('Y-axis')
ax.set_zlabel('Z-axis')
ax.set_title('3D Countour Plot of f(x,y) = cos(x+y)')
plt.show()

# %%
#1
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits import mplot3d

x = np.linspace(0, 2*np.pi, 100)
y = np.linspace(0, 2*np.pi, 100)
X, Y = np.meshgrid(x,y)
Z = X ** 3 + Y ** 2

fig = plt.figure(figsize=(9,9))

ax=plt.axes(projection='3d')
ax.contour3D(X,Y,Z,50,cmap='viridis')
ax.set_xlabel('X-axis')
ax.set_ylabel('Y-axis')
ax.set_zlabel('Z-axis')
ax.set_title('3D Countour Plot of f(x,y) = $x^{3} + y^{2}$')
plt.show()

# %%
#2
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits import mplot3d

x = np.linspace(-2*np.pi, 2*np.pi, 100)
y = np.linspace(-2*np.pi, 2*np.pi, 100)
X, Y = np.meshgrid(x,y)
Z = np.sin(X**2 + Y)

fig = plt.figure(figsize=(9,9))
    
ax=plt.axes(projection='3d')
ax.contour3D(X,Y,Z,50,cmap='viridis')
ax.set_xlabel('X-axis')
ax.set_ylabel('Y-axis')
ax.set_zlabel('Z-axis')
ax.set_title('3D Countour Plot of f(x,y) = $sin(x^{2} + y)$')
plt.show()

# %%
#3
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits import mplot3d

x = np.linspace(-2*np.pi, 2*np.pi, 100)
y = np.linspace(-2*np.pi, 2*np.pi, 100)
X, Y = np.meshgrid(x,y)
Z = np.sin(X + Y) + np.cos(X)

fig = plt.figure(figsize=(9,9))

ax=plt.axes(projection='3d')
ax.contour3D(X,Y,Z,50,cmap='viridis')
ax.set_xlabel('X-axis')
ax.set_ylabel('Y-axis')
ax.set_zlabel('Z-axis')
ax.set_title('3D Countour Plot of f(x,y) = sin(x + y) + cos(x)')
plt.show()

# %%
#4
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits import mplot3d

x = np.linspace(-2*np.pi, 2*np.pi, 100)
y = np.linspace(-2*np.pi, 2*np.pi, 100)
X, Y = np.meshgrid(x,y)
Z = np.sin(X) + np.cos(X)

fig = plt.figure(figsize=(9,9))

ax=plt.axes(projection='3d')
ax.contour3D(X,Y,Z,50,cmap='plasma')
ax.set_xlabel('X-axis')
ax.set_ylabel('Y-axis')
ax.set_zlabel('Z-axis')
ax.set_title('3D Countour Plot of f(x,y) = sin(x) + cos(x)')
plt.show()

# %%
#5
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits import mplot3d

x = np.linspace(-6, 6, 100)
y = np.linspace(-6, 6, 100)
X, Y = np.meshgrid(x,y)
Z = np.sin(X ** 2 + Y ** 2)

fig = plt.figure(figsize=(9,9))

ax=plt.axes(projection='3d')
ax.contour3D(X,Y,Z,50,cmap='inferno')
ax.set_xlabel('X-axis')
ax.set_ylabel('Y-axis')
ax.set_zlabel('Z-axis')
ax.set_title('3D Countour Plot of f(x,y) = sin(x^{2} + y^{2})$')
plt.show()

# %%
#6
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits import mplot3d

x = np.linspace(-6, 6, 100)
y = np.linspace(-6, 6, 100)
X, Y = np.meshgrid(x,y)
Z = X ** 2 + Y ** 2

fig = plt.figure(figsize=(9,9))

ax=plt.axes(projection='3d')
ax.contour3D(X,Y,Z,50,cmap='magma')
ax.set_xlabel('X-axis')
ax.set_ylabel('Y-axis')
ax.set_zlabel('Z-axis')
ax.set_title('3D Countour Plot of f(x,y) = $x^{2} + y^{2}$')
plt.show()

# %%
#7
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits import mplot3d

x = np.linspace(-1, 1, 100)
y = np.linspace(-1, 1, 100)
X, Y = np.meshgrid(x,y)
Z = np.exp(-X ** 2  -Y ** 2)

fig = plt.figure(figsize=(9,9))

ax=plt.axes(projection='3d')
ax.contour3D(X,Y,Z,50,cmap='coolwarm')
ax.set_xlabel('X-axis')
ax.set_ylabel('Y-axis')
ax.set_zlabel('Z-axis')
ax.set_title('3D Countour Plot of f(x,y) = $e^{-x^{2} -y^{2}}$')
plt.show()

# %%
#8
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits import mplot3d

x = np.linspace(-1, 1, 100)
y = np.linspace(-1, 1, 100)
X, Y = np.meshgrid(x,y)
Z = (np.sin(4*X) - np.cos(5*Y))/5

fig = plt.figure(figsize=(9,9))

ax=plt.axes(projection='3d')
ax.contour3D(X,Y,Z,50,cmap='RdBu')
ax.set_xlabel('X-axis')
ax.set_ylabel('Y-axis')
ax.set_zlabel('Z-axis')
ax.set_title('3D Countour Plot of f(x,y) = sin(4x) - cos(5y)/5')
plt.show()
